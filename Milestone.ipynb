# %%
##train_sample = pd.DataFrame()
##files_directory = os.listdir("../train_simplified")
##for file in files_directory:
##    train_sample = train_sample.append(pd.read_csv('../train_simplified/' + file, index_col='key_id', nrows=10))
# Shuffle data
##train_sample = shuffle(train_sample, random_state=123)
##train = pd.DataFrame()
##for file in files_directory[:185]:
##    train = train.append(pd.read_csv('../train_simplified/' + file, index_col='key_id', usecols=[1, 2, 3, 5]))
# Shuffle data
##train = shuffle(train, random_state=123)

# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

os.chdir('C:/Users/carolruisi/')

airplane = pd.read_csv('airplane.csv')
airplane = airplane[airplane.recognized]air['timestamp'] = pd.to_datetime(hottub.timestamp)
hottub = hottub.sort_values(by='timestamp', ascending=False)[:-10000]
hottub['drawing'] = hottub['drawing'].apply(ast.literal_eval)
hottub.head()

os.chdir('C:/Users/carolruisi/airplane/original')
for i, drawing in enumerate(hottub.drawing):
    fig, axs = plt.subplots(nrows=1, ncols=1)
    for x, y in drawing:
        axs.plot(x, -np.array(y), lw=3)
        axs.axis('off')
    fig.savefig('airplane'+str(i)+'.png');

# transformations, such as:
# - resizing
# - translation
# - rotation

##--Resizing
os.chdir('C:/Users/carolruisi/airplane/resize')
files_directory = os.listdir("C:/Users/carolruisi/airplane/original")
i=0
for file in files_directory:
    img = cv2.imread('C:/Users/carolruisi/airplane/original/' + file,0)
    res = cv2.resize(img,None,fx=0.5, fy=0.5, interpolation = cv2.INTER_CUBIC)
    #height, width = img.shape[:2]
    #res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
    cv2.imwrite('res'+str(i)+'.png',res)
    i +=1
    
##-- translation
os.chdir('C:/Users/carolruisi/airplane/wrapAffine')
files_directory = os.listdir("C:/Users/carolruisi/airplane/original")
i=0
for file in files_directory:
    img = cv2.imread('C:/Users/carolruisi/airplane/original/' + file,0)
    rows,cols = img.shape[:2]
    M = np.float32([[1,0,100],[0,1,50]])
    dst = cv2.warpAffine(img,M,(cols,rows))
    cv2.imwrite('dst'+str(i)+'.png',dst)
    i +=1

##- rotation 
os.chdir('C:/Users/carolruisi/airplane/rotation')
files_directory = os.listdir("C:/Users/carolruisi/airplane/original")
i=0
for file in files_directory:
    img = cv2.imread('C:/Users/carolruisi/airplane/original/' + file,0)
    rows,cols = img.shape[:2]
    print(rows)
    M = cv2.getRotationMatrix2D((cols/2,rows/2),45,1)
    rot = cv2.warpAffine(img,M,(cols,rows))
    cv2.imwrite('rot'+str(i)+'.png',rot)
    i +=1

##--erosion/opening
kernel = np.ones((5,5),np.uint8)
os.chdir('C:/Users/carolruisi/airplane/erosion')
files_directory = os.listdir("C:/Users/carolruisi/airplane/original")
i=0
for file in files_directory:
    img = cv2.imread('C:/Users/carolruisi/airplane/original/' + file,0)
    #opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
    erosion = cv2.erode(img,kernel,iterations = 1)
    cv2.imwrite('erosion'+str(i)+'.png',erosion)
    i +=1
    

##--dilation
os.chdir('C:/Users/carolruisi/airplane/dilation')
files_directory = os.listdir("C:/Users/carolruisi/airplane/original")
i=0
for file in files_directory:
    img = cv2.imread('C:/Users/carolruisi/airplane/original/' + file,0)
    dilation = cv2.dilate(img,kernel,iterations = 1)
    cv2.imwrite('dilation'+str(i)+'.png',dilation)
    i +=1
   

 
##--Morphological Gradient
os.chdir('C:/Users/carolruisi/airplane/Morpho')
files_directory = os.listdir("C:/Users/carolruisi/airplane/original")
i=0
for file in files_directory:
    img = cv2.imread('C:/Users/carolruisi/airplane/original/' + file,0)
    rows,cols = img.shape[:2]
    gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, (cols,rows))
    #dilation = cv2.dilate(img,(cols,rows),iterations = 1)
    #cv2.imwrite('dilation'+str(i)+'.png',dilation)
    cv2.imwrite('dilation'+str(i)+'.png',gradient)
    i +=1
